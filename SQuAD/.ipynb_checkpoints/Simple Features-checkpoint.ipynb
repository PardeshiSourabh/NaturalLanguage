# %% [markdown]
# # Creating Sentence Embeddings for SQuAD

# %%
import pandas as pd

# %% [markdown]
# ## Converting Json to Pandas DataFrame for better Visualization

# %%
X = pd.read_json("data/train-v1.1.json")

# %% [markdown]
# We can see that the SQuAD dataset is structured and close-domained i.e. it only contains selected question answer pairs.
# Context is the paragraph from the article within which the answer is located. This text is under the key 'paragraphs'. Every Context contains a set of questions and their respective answers that are placed under the key 'answers'. The dataset also provides the index of the character where the answer to the question starts. Let's go ahead and convert this information into an excel sheet for better and easier data handling.

# %%
X.iloc[6,0]['paragraphs'][56]
# Out:
# {'context': 'P. Christiaan Klieger, an anthropologist and scholar of the California Academy of Sciences in San Francisco, writes that the vice royalty of the Sakya regime installed by the Mongols established a patron and priest relationship between Tibetans and Mongol converts to Tibetan Buddhism. According to him, the Tibetan lamas and Mongol khans upheld a "mutual role of religious prelate and secular patron," respectively. He adds that "Although agreements were made between Tibetan leaders and Mongol khans, Ming and Qing emperors, it was the Republic of China and its Communist successors that assumed the former imperial tributaries and subject states as integral parts of the Chinese nation-state."',
#  'qas': [{'answers': [{'answer_start': 304,
#      'text': 'the Tibetan lamas and Mongol khans'}],
#    'id': '56ce2752aab44d1400b884d2',
#    'question': 'Who does P. Christiaan Klieger claim to have had a mutual role of religious prelate?'},
#   {'answers': [{'answer_start': 534,
#      'text': 'the Republic of China and its Communist successors'}],
#    'id': '56ce2752aab44d1400b884d3',
#    'question': 'Who does P. Christiaan Klieger believe undertook the former imperial tributaries?'},
#   {'answers': [{'answer_start': 56,
#      'text': 'the California Academy of Sciences in San Francisco'}],
#    'id': '56ce2752aab44d1400b884d4',
#    'question': 'Where does P. Christiaan Klieger work?'},
#   {'answers': [{'answer_start': 171, 'text': 'the Mongols'}],
#    'id': '56ce2752aab44d1400b884d5',
#    'question': 'Who was the  vice royalty of the Sakya regime established by?'},
#   {'answers': [{'answer_start': 197,
#      'text': 'patron and priest relationship'}],
#    'id': '56ce2752aab44d1400b884d6',
#    'question': 'The Sakya regime established what kind of relationship between the Tibetans and Mongol converts?'}]}

# %%
contexts = []
questions = []
answer_texts = []
starts_at = []

# %%
for data in range(X.shape[0]):
    title = X.iloc[data,0]['paragraphs']
    for subtitle in title:
        for qa in subtitle['qas']:
            questions.append(qa['question'])
            starts_at.append(qa['answers'][0]['answer_start'])
            answer_texts.append(qa['answers'][0]['text'])
            contexts.append(subtitle['context'])

# %% [markdown]
# Create a single Dataframe with all data

# %%
df = pd.DataFrame({"context":contexts, "question": questions, "answer_start": starts_at, "text": answer_texts})

# %%
df.to_csv("data/train.csv", index = None)

# %%
df.shape
# Out:
# (87599, 4)

# %% [markdown]
# ## Using InferSent for creating embeddings and dumping data dictionary to pickle

# %%
uniquecontext = list(df['context'].drop_duplicates().reset_index(drop= True))

# %%
from textblob import TextBlob

tb = TextBlob(" ".join(uniquecontext))
sentences = [item.raw for item in tb.sentences]

# %% [markdown]
# #### Transfer Learning:  Import InferSent LSTM model with pretrained GloVe vectors for creating sentence embeddings

# %%
import sys
sys.path.append('InferSent')
import torch

from models import InferSent
model_version = 1
MODEL_PATH = "InferSent/encoder/infersent%s.pkl" % model_version
params_model = {'bsize': 64, 'word_emb_dim': 300, 'enc_lstm_dim': 2048,
                'pool_type': 'max', 'dpout_model': 0.0, 'version': model_version}
model = InferSent(params_model)
model.load_state_dict(torch.load(MODEL_PATH))
use_cuda = True
model = model.cuda()

# %%
model.set_w2v_path("InferSent/glove/glove.840B.300d.txt")

# %%
model.build_vocab(sentences, tokenize=True)
# Out:
# Found 88993(/109718) words with w2v vectors
# Vocab size : 88993

# %% [markdown]
# This Step is just for visualization purposes. If you don't have a GPU, this step will take a lot of time. Just load the pre created embeddings from embedding1.pkl and embedding2.pkl as specified below

# %%
with open("data/embedding1.pickle", "rb") as f:
    d1 = pickle.load(f)

with open("data/embedding2.pickle", "rb") as f:
    d2 = pickle.load(f)

# %%
dict_embeddings = {}
for i in range(len(sentences)):
    print(i)
    dict_embeddings[sentences[i]] = model.encode([sentences[i]], tokenize=True)

# %%
questions = list(df["question"])

# %%
len(questions)
# Out:
# 87599

# %%
d1 = {key:dict_embeddings[key] for i, key in enumerate(dict_embeddings) if i % 2 == 0}
d2 = {key:dict_embeddings[key] for i, key in enumerate(dict_embeddings) if i % 2 == 1}

# %%
import pickle

with open('data/embedding1.pickle', 'wb') as handle:
    pickle.dump(d1, handle)
with open('data/embedding2.pickle', 'wb') as handle:
    pickle.dump(d2, handle)

# %%
X_train = pd.read_csv('data/train.csv')

# %%
X_train
# Out:
#        answer_start                                            context  \
# 0               515  Architecturally, the school has a Catholic cha...
# 1               188  Architecturally, the school has a Catholic cha...
# 2               279  Architecturally, the school has a Catholic cha...
# 3               381  Architecturally, the school has a Catholic cha...
# 4                92  Architecturally, the school has a Catholic cha...
# 5               248  As at most other universities, Notre Dame's st...
# 6               441  As at most other universities, Notre Dame's st...
# 7               598  As at most other universities, Notre Dame's st...
# 8               126  As at most other universities, Notre Dame's st...
# 9               908  As at most other universities, Notre Dame's st...
# 10              119  The university is the major seat of the Congre...
# 11              145  The university is the major seat of the Congre...
# 12              234  The university is the major seat of the Congre...
# 13              356  The university is the major seat of the Congre...
# 14              675  The university is the major seat of the Congre...
# 15              487  The College of Engineering was established in ...
# 16               46  The College of Engineering was established in ...
# 17              126  The College of Engineering was established in ...
# 18              271  The College of Engineering was established in ...
# 19              155  The College of Engineering was established in ...
# 20              496  All of Notre Dame's undergraduate students are...
# 21               68  All of Notre Dame's undergraduate students are...
# 22              155  All of Notre Dame's undergraduate students are...
# 23              647  All of Notre Dame's undergraduate students are...
# 24              358  The university first offered graduate degrees,...
# 25              624  The university first offered graduate degrees,...
# 26             1163  The university first offered graduate degrees,...
# 27               92  The university first offered graduate degrees,...
# 28              757  The university first offered graduate degrees,...
# 29                4  The Joan B. Kroc Institute for International P...
# ...             ...                                                ...
# 87598                        Kathmandu Metropolitan City
#
# [87599 rows x 4 columns]

# %%
dict_emb = dict(d1)
dict_emb.update(d2)

# %%
len(dict_emb)
# Out:
# 179862

# %%
X_train.dropna(inplace=True)

# %%
X_train.shape
# Out:
# (87598, 4)

# %%
def get_target(x):
    idx = -1
    for i in range(len(x["sentences"])):
        if x["text"] in x["sentences"][i]: idx = i
    return idx

def process(train):
    
    train['sentences'] = train['context'].apply(lambda x: [item.raw for item in TextBlob(x).sentences])
    train["target"] = train.apply(get_target, axis = 1)
    train['sent_emb'] = train['sentences'].apply(lambda x: [dict_emb[item][0] if item in\
                                                           dict_emb else np.zeros(4096) for item in x])
    train['quest_emb'] = train['question'].apply(lambda x: dict_emb[x] if x in dict_emb else np.zeros(4096) )
    
    return train

# %%
import numpy as np

X_train = process(X_train)

# %%
X_train.head(5)
# Out:
#    answer_start                                            context  \
# 0           515  Architecturally, the school has a Catholic cha...
# 1           188  Architecturally, the school has a Catholic cha...
# 2           279  Architecturally, the school has a Catholic cha...
# 3           381  Architecturally, the school has a Catholic cha...
# 4            92  Architecturally, the school has a Catholic cha...
#
#                                             question  \
# 0  To whom did the Virgin Mary allegedly appear i...
# 1  What is in front of the Notre Dame Main Building?
# 2  The Basilica of the Sacred heart at Notre Dame...
# 3                  What is the Grotto at Notre Dame?
# 4  What sits on top of the Main Building at Notre...
#
#                                       text  \
# 0               Saint Bernadette Soubirous
# 1                a copper statue of Christ
# 2                        the Main Building
# 3  a Marian place of prayer and reflection
# 4       a golden statue of the Virgin Mary
#
#                                            sentences  target  \
# 0  [Architecturally, the school has a Catholic ch...       5
# 1  [Architecturally, the school has a Catholic ch...       2
# 2  [Architecturally, the school has a Catholic ch...       3
# 3  [Architecturally, the school has a Catholic ch...       4
# 4  [Architecturally, the school has a Catholic ch...       1
#
#                                             sent_emb  \
# 0  [[0.05519996, 0.0501314, 0.047870375, 0.016248...
# 1  [[0.05519996, 0.0501314, 0.047870375, 0.016248...
# 2  [[0.05519996, 0.0501314, 0.047870375, 0.016248...
# 3  [[0.05519996, 0.0501314, 0.047870375, 0.016248...
# 4  [[0.05519996, 0.0501314, 0.047870375, 0.016248...
#
#                                            quest_emb
# 0  [[0.11010079, 0.11422941, 0.115608975, 0.05489...
# 1  [[0.10951651, 0.11030627, 0.052100062, 0.03053...
# 2  [[0.011956477, 0.14930707, 0.026600495, 0.0527...
# 3  [[0.0711433, 0.05411832, -0.013959841, 0.05310...
# 4  [[0.16133596, 0.1503958, 0.09225755, 0.0404580...

# %%
def cosine_similarity(x):
    li = []
    for item in x["sent_emb"]:
        li.append(spatial.distance.cosine(item, x["quest_emb"][0]))
    return li

def pred_idx(distances):
    return np.argmin(distances)

def predictions(train):
    
    train["cosine_sim"] = train.apply(cosine_similarity, axis = 1)
    train["diff"] = (train["quest_emb"] - train["sent_emb"])**2
    train["euclidean_dis"] = train["diff"].apply(lambda x: list(np.sum(x, axis = 1)))
    del train["diff"]
    
    train["pred_idx_cos"] = train["cosine_sim"].apply(lambda x: pred_idx(x))
    train["pred_idx_euc"] = train["euclidean_dis"].apply(lambda x: pred_idx(x))
    
    return train

# %%
from scipy import spatial

predicted = predictions(X_train)
# Out:
# e:\anaconda3\envs\squad\lib\site-packages\scipy\spatial\distance.py:698: RuntimeWarning: invalid value encountered in double_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)

# %%
predicted.head(10)
# Out:
#    answer_start                                            context  \
# 0           515  Architecturally, the school has a Catholic cha...
# 1           188  Architecturally, the school has a Catholic cha...
# 2           279  Architecturally, the school has a Catholic cha...
# 3           381  Architecturally, the school has a Catholic cha...
# 4            92  Architecturally, the school has a Catholic cha...
# 5           248  As at most other universities, Notre Dame's st...
# 6           441  As at most other universities, Notre Dame's st...
# 7           598  As at most other universities, Notre Dame's st...
# 8           126  As at most other universities, Notre Dame's st...
# 9           908  As at most other universities, Notre Dame's st...
#
#                                             question  \
# 0  To whom did the Virgin Mary allegedly appear i...
# 1  What is in front of the Notre Dame Main Building?
# 2  The Basilica of the Sacred heart at Notre Dame...
# 3                  What is the Grotto at Notre Dame?
# 4  What sits on top of the Main Building at Notre...
# 5  When did the Scholastic Magazine of Notre dame...
# 6   How often is Notre Dame's the Juggler published?
# 7  What is the daily student paper at Notre Dame ...
# 8  How many student news papers are found at Notr...
# 9  In what year did the student paper Common Sens...
#
#                                       text  \
# 0               Saint Bernadette Soubirous
# 1                a copper statue of Christ
# 2                        the Main Building
# 3  a Marian place of prayer and reflection
# 4       a golden statue of the Virgin Mary
# 5                           September 1876
# 6                                    twice
# 7                             The Observer
# 8                                    three
# 9                                     1987
#
#                                            sentences  target  \
# 0  [Architecturally, the school has a Catholic ch...       5
# 1  [Architecturally, the school has a Catholic ch...       2
# 2  [Architecturally, the school has a Catholic ch...       3
# 3  [Architecturally, the school has a Catholic ch...       4
# 4  [Architecturally, the school has a Catholic ch...       1
# 5  [As at most other universities, Notre Dame's s...       2
# 6  [As at most other universities, Notre Dame's s...       3
# 7  [As at most other universities, Notre Dame's s...       9
# 8  [As at most other universities, Notre Dame's s...       9
# 9  [As at most other universities, Notre Dame's s...       7
#
#                                             sent_emb  \
# 0  [[0.05519996, 0.0501314, 0.047870375, 0.016248...
# 1  [[0.05519996, 0.0501314, 0.047870375, 0.016248...
# 2  [[0.05519996, 0.0501314, 0.047870375, 0.016248...
# 3  [[0.05519996, 0.0501314, 0.047870375, 0.016248...
# 4  [[0.05519996, 0.0501314, 0.047870375, 0.016248...
# 5  [[0.09720327, 0.09345725, 0.054660242, 0.04843...
# 6  [[0.09720327, 0.09345725, 0.054660242, 0.04843...
# 7  [[0.09720327, 0.09345725, 0.054660242, 0.04843...
# 8  [[0.09720327, 0.09345725, 0.054660242, 0.04843...
# 9  [[0.09720327, 0.09345725, 0.054660242, 0.04843...
#
#                                            quest_emb  \
# 0  [[0.11010079, 0.11422941, 0.115608975, 0.05489...
# 1  [[0.10951651, 0.11030627, 0.052100062, 0.03053...
# 2  [[0.011956477, 0.14930707, 0.026600495, 0.0527...
# 3  [[0.0711433, 0.05411832, -0.013959841, 0.05310...
# 4  [[0.16133596, 0.1503958, 0.09225755, 0.0404580...
# 5  [[0.016918724, 0.12084099, 0.013292058, 0.0587...
# 6  [[0.07944553, 0.11071574, 0.11615732, 0.045065...
# 7  [[0.0711433, 0.05411832, 0.02641398, 0.0866460...
# 8  [[0.06699271, 0.050647143, 0.118103534, 0.0667...
# 9  [[0.042654388, 0.13311043, 0.112292886, 0.0977...
#
#                                           cosine_sim  \
# 0  [0.42473626136779785, 0.3640499711036682, 0.34...
# 1  [0.45407456159591675, 0.32262009382247925, 0.3...
# 2  [0.3958578109741211, 0.2917083501815796, 0.309...
# 3  [0.49006974697113037, 0.4060605764389038, 0.45...
# 4  [0.4777514934539795, 0.2891119122505188, 0.341...
# 5  [0.2747580409049988, 0.3731493353843689, 0.280...
# 6  [0.29136353731155396, 0.44691193103790283, 0.3...
# 7  [0.24287956953048706, 0.38149863481521606, 0.3...
# 8  [0.18055570125579834, 0.3603665828704834, 0.34...
# 9  [0.2252199649810791, 0.36460912227630615, 0.26...
#
#                                        euclidean_dis  pred_idx_cos  \
# 0  [14.563859, 15.262213, 17.398178, 14.272491, 1...             5
# 1  [12.889506, 12.285219, 16.843704, 8.361172, 11...             3
# 2  [11.857297, 11.392319, 15.061656, 7.184714, 8....             3
# 3  [13.317537, 15.017247, 20.81268, 10.511387, 10...             3
# 4  [15.0888195, 11.612734, 16.684145, 9.71824, 12...             3
# 5  [11.473504, 16.305737, 14.419686, 11.785967, 1...             5
# 6  [12.094654, 19.268333, 17.051125, 12.115431, 1...             5
# 7  [10.40575, 17.056553, 16.048374, 12.6742735, 1...             5
# 8  [7.8146877, 16.114155, 17.537537, 12.886263, 1...             0
# 9  [9.867832, 16.703403, 13.726372, 11.037147, 12...             5
#
#    pred_idx_euc
# 0             5
# 1             3
# 2             3
# 3             3
# 4             3
# 5             4
# 6             4
# 7             0
# 8             0
# 9             0

# %%
predicted.to_csv("data/newdata.csv", index=None)

# %%
def accuracy(target, predicted):
    
    acc = (target==predicted).sum()/len(target)
    
    return acc

# %%
print(accuracy(predicted["target"], predicted["pred_idx_euc"]))
# Out:
# 0.4471106646270463

# %%
print(accuracy(predicted["target"], predicted["pred_idx_cos"]))
# Out:
# 0.6333477933286148

# %%
predicted.iloc[65000,:]
# Out:
# answer_start                                                   546
# context          Socioeconomic factors, in combination with ear...
# question         What has led to many tragic instances of event...
# text                                                        Racism
# sentences        [Socioeconomic factors, in combination with ea...
# target                                                           3
# sent_emb         [[0.098147884, 0.1247487, 0.14421512, 0.060331...
# quest_emb        [[0.079051174, 0.08900199, 0.13616362, 0.06939...
# cosine_sim       [0.2518765926361084, 0.24583172798156738, 0.24...
# euclidean_dis           [11.059026, 11.683056, 11.02791, 3.251983]
# pred_idx_cos                                                     3
# pred_idx_euc                                                     3
# Name: 65000, dtype: object

# %%
ct,k = 0,0
for i in range(predicted.shape[0]):
    if predicted.iloc[i,10] != predicted.iloc[i,5]:
        k += 1
        if predicted.iloc[i,11] == predicted.iloc[i,5]:
            ct += 1

ct, k
# Out:
# (5534, 32118)

# %%
label = []
for i in range(predicted.shape[0]):
    if predicted.iloc[i,10] == predicted.iloc[i,11]:
        label.append(predicted.iloc[i,10])
    else:
        label.append((predicted.iloc[i,10],predicted.iloc[i,10]))

# %%
ct = 0
for i in range(75206):
    item = predicted["target"][i]
    try:
        if label[i] == predicted["target"][i]: ct +=1
    except:
        if item in label[i]: ct +=1

# %% [markdown]
# # Combining Accuracy of features

# %%
ct/75206
# Out:
# 0.6364385820280297
